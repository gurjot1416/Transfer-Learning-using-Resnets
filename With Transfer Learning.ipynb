# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
import os
import matplotlib.pyplot as plt
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from pathlib import Path
from PIL import Image

# %%
if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")

# Check TensorFlow version and GPU device
print(f'TensorFlow version: {tf.__version__}')
print(f'GPU device: {tf.config.list_physical_devices("GPU")}')
# Out:
# GPU found
# TensorFlow version: 2.14.0
# GPU device: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.device('/device:GPU:0')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = Path("/content/drive/MyDrive/Garbage classification")

# %%
print(data_dir)
# Out:
# /content/drive/MyDrive/Garbage classification

# %%
if os.path.exists(data_dir):
    classes = os.listdir(data_dir)
    print(classes)
else:
    print(f"The directory '{data_dir}' does not exist.")
# Out:
# ['metal', 'cardboard', 'paper', 'glass', 'plastic', 'trash']

# %%
glass = list(data_dir.glob('glass/*'))
print(glass[0])
PIL.Image.open(str(glass[0]))
# Out:
# /content/drive/MyDrive/Garbage classification/glass/glass105.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>

# %%
metal = list(data_dir.glob('metal/*'))
cardboard = list(data_dir.glob('cardboard/*'))
paper = list(data_dir.glob('paper/*'))
plastic = list(data_dir.glob('plastic/*'))
trash = list(data_dir.glob('trash/*'))

# %%
PIL.Image.open(str(glass[8])).size
# Out:
# (512, 384)

# %%
# Define the classes
classes = ['glass', 'metal', 'cardboard', 'paper', 'plastic', 'trash']

# Iterate through each class
for class_name in classes:
    class_images = list(data_dir.glob(f'{class_name}/*'))

    # Check if there are any images in the class
    if class_images:
        # Get the first image in the class
        first_image_path = class_images[0]

        # Print the size of the first image in the class
        img = Image.open(str(first_image_path))
        width, height = img.size
        print(f"Class: {class_name}, First Image: {first_image_path.name}, Size: {width} x {height}")
    else:
        print(f"No images found for class: {class_name}")
# Out:
# Class: glass, First Image: glass105.jpg, Size: 512 x 384
# Class: metal, First Image: metal114.jpg, Size: 512 x 384
# Class: cardboard, First Image: cardboard118.jpg, Size: 512 x 384
# Class: paper, First Image: paper127.jpg, Size: 512 x 384
# Class: plastic, First Image: plastic108.jpg, Size: 512 x 384
# Class: trash, First Image: trash91.jpg, Size: 512 x 384

# %%
img_height, img_width = 180, 180
batch_size = 32
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset = "training",
    seed=123,
    label_mode='categorical',
    image_size=(img_height, img_width),
    batch_size= batch_size
)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset = "validation",
    seed=123,
    label_mode='categorical',
    image_size=(img_height, img_width),
    batch_size= batch_size
)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
class_names = train_ds.class_names

# Function to plot a batch of images with label names
def plot_images(images, labels, class_names):
    plt.figure(figsize=(15, 10))
    for i in range(len(images)):
        plt.subplot(4, 8, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = int(tf.argmax(labels[i]))
        plt.title(f"Label: {class_names[label_index]}")
        plt.axis("off")
    plt.show()

# Iterate through the training dataset and print the images of the first batch
for images, labels in train_ds.take(1):
    plot_images(images, labels, class_names)

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
# net = models.resnet18(pretrained=True)

# %% [markdown]
# # **Training the model**

# %%
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
resnet_ml = Sequential()

pretrain = tf.keras.applications.ResNet50(include_top= False,
                                          input_shape=(180,180,3),
                                          pooling='avg', classes=6,
                                          weights = 'imagenet')
for layers in pretrain.layers:
  layers.trainable=False


resnet_ml.add(pretrain)
# resnet_ml.add(Flatten())
resnet_ml.add(Flatten())
resnet_ml.add(Dense(units=1024, activation='relu'))  # use ReLU activation function

resnet_ml.add(Dense(units=128, activation='relu')) # use ReLU activation function

resnet_ml.add(Dense(6, activation='softmax'))

# %%
from tensorflow.keras.layers import RandomRotation, RandomFlip, RandomContrast, RandomBrightness
data_augmentation = Sequential([

    tf.keras.layers.experimental.preprocessing.RandomRotation(0.45),

    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),

    tf.keras.layers.RandomContrast(factor=0.2),  # Adjust the factor as needed
    tf.keras.layers.RandomBrightness(factor=0.2),  # Adjust the factor as needed
])

augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
resnet_ml.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 25817862 (98.49 MB)
# Trainable params: 2230150 (8.51 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %% [markdown]
# Training the added layers.

# %%
resnet_ml.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# Define callbacks
checkpoint_path = "/content/drive/MyDrive/10_layertrain_lr_2g.h5"
model_checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
epochs=3
history = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_checkpoint]
)
# Out:
# Epoch 1/10
# 64/64 [==============================] - ETA: 0s - loss: 0.9341 - accuracy: 0.6464
# Epoch 1: val_accuracy improved from -inf to 0.68119, saving model to /content/drive/MyDrive/10_layertrain_lr_2g.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 64/64 [==============================] - 140s 2s/step - loss: 0.9341 - accuracy: 0.6464 - val_loss: 0.8807 - val_accuracy: 0.6812
# Epoch 2/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.6118 - accuracy: 0.7917
# Epoch 2: val_accuracy improved from 0.68119 to 0.80198, saving model to /content/drive/MyDrive/10_layertrain_lr_2g.h5
# 64/64 [==============================] - 18s 275ms/step - loss: 0.6115 - accuracy: 0.7918 - val_loss: 0.5672 - val_accuracy: 0.8020
# Epoch 3/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.5175 - accuracy: 0.8011
# Epoch 3: val_accuracy improved from 0.80198 to 0.81782, saving model to /content/drive/MyDrive/10_layertrain_lr_2g.h5
# 64/64 [==============================] - 17s 262ms/step - loss: 0.5177 - accuracy: 0.8007 - val_loss: 0.5291 - val_accuracy: 0.8178
# Epoch 4/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.4455 - accuracy: 0.8318
# Epoch 4: val_accuracy improved from 0.81782 to 0.82772, saving model to /content/drive/MyDrive/10_layertrain_lr_2g.h5
# 64/64 [==============================] - 16s 241ms/step - loss: 0.4450 - accuracy: 0.8318 - val_loss: 0.5010 - val_accuracy: 0.8277
# Epoch 5/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.3861 - accuracy: 0.8616
# Epoch 5: val_accuracy did not improve from 0.82772
# 64/64 [==============================] - 15s 224ms/step - loss: 0.3856 - accuracy: 0.8620 - val_loss: 0.5892 - val_accuracy: 0.7980
# Epoch 6/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8586
# Epoch 6: val_accuracy did not improve from 0.82772
# 64/64 [==============================] - 15s 215ms/step - loss: 0.3342 - accuracy: 0.8591 - val_loss: 0.5579 - val_accuracy: 0.8079
# Epoch 7/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.3348 - accuracy: 0.8735
# Epoch 7: val_accuracy did not improve from 0.82772
# 64/64 [==============================] - 15s 224ms/step - loss: 0.3356 - accuracy: 0.8734 - val_loss: 0.5426 - val_accuracy: 0.8158
# Epoch 8/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2891 - accuracy: 0.8889
# Epoch 8: val_accuracy did not improve from 0.82772
# 64/64 [==============================] - 15s 230ms/step - loss: 0.2884 - accuracy: 0.8892 - val_loss: 0.5197 - val_accuracy: 0.8257
# Epoch 9/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2295 - accuracy: 0.9162
# Epoch 9: val_accuracy did not improve from 0.82772
# 64/64 [==============================] - 15s 229ms/step - loss: 0.2289 - accuracy: 0.9164 - val_loss: 0.5310 - val_accuracy: 0.8238
# Epoch 10/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2576 - accuracy: 0.9048
# Epoch 10: val_accuracy improved from 0.82772 to 0.84554, saving model to /content/drive/MyDrive/10_layertrain_lr_2g.h5
# 64/64 [==============================] - 17s 254ms/step - loss: 0.2570 - accuracy: 0.9050 - val_loss: 0.4968 - val_accuracy: 0.8455

# %%
from tensorflow.keras.models import load_model
saved_model_path = "/content/drive/MyDrive/10_layertrain_lr_2g.h5"
best_model_1 = load_model(saved_model_path)

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.4, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# Training the complete model

# %%
resnet_ml.optimizer.get_config()["name"]
# Out:
# 'Adam'

# %%
checkpoint_path = "/content/drive/MyDrive/resnet_50_updated_lr_2g.h5"
model_checkpoint_full = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
for layers in resnet_ml.layers:
  layers.trainable = True

resnet_ml.compile(optimizer=Adam(learning_rate=0.0000055), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
resnet_ml.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 25817862 (98.49 MB)
# Trainable params: 25764742 (98.28 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %%
epochs=100
history_50 = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_checkpoint_full]
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.7453
# Epoch 1: val_accuracy improved from -inf to 0.87327, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 61s 364ms/step - loss: 0.7347 - accuracy: 0.7453 - val_loss: 0.4401 - val_accuracy: 0.8733
# Epoch 2/100
# 64/64 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8477
# Epoch 2: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 19s 286ms/step - loss: 0.4248 - accuracy: 0.8477 - val_loss: 0.4507 - val_accuracy: 0.8634
# Epoch 3/100
# 64/64 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8897
# Epoch 3: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 20s 305ms/step - loss: 0.3368 - accuracy: 0.8897 - val_loss: 0.4661 - val_accuracy: 0.8673
# Epoch 4/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.9011
# Epoch 4: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 19s 289ms/step - loss: 0.2883 - accuracy: 0.9011 - val_loss: 0.4702 - val_accuracy: 0.8515
# Epoch 5/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9159
# Epoch 5: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 19s 293ms/step - loss: 0.2304 - accuracy: 0.9159 - val_loss: 0.4716 - val_accuracy: 0.8594
# Epoch 6/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9204
# Epoch 6: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 20s 296ms/step - loss: 0.2258 - accuracy: 0.9204 - val_loss: 0.4549 - val_accuracy: 0.8594
# Epoch 7/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9342
# Epoch 7: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 20s 297ms/step - loss: 0.1876 - accuracy: 0.9342 - val_loss: 0.4493 - val_accuracy: 0.8653
# Epoch 8/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9327
# Epoch 8: val_accuracy did not improve from 0.87327
# 64/64 [==============================] - 19s 285ms/step - loss: 0.1845 - accuracy: 0.9327 - val_loss: 0.4495 - val_accuracy: 0.8653
# Epoch 9/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9441
# Epoch 9: val_accuracy improved from 0.87327 to 0.87921, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 26s 399ms/step - loss: 0.1611 - accuracy: 0.9441 - val_loss: 0.4474 - val_accuracy: 0.8792
# Epoch 10/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9456
# Epoch 10: val_accuracy did not improve from 0.87921
# 64/64 [==============================] - 19s 295ms/step - loss: 0.1597 - accuracy: 0.9456 - val_loss: 0.4350 - val_accuracy: 0.8792
# Epoch 11/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9545
# Epoch 11: val_accuracy did not improve from 0.87921
# 64/64 [==============================] - 19s 289ms/step - loss: 0.1337 - accuracy: 0.9545 - val_loss: 0.4360 - val_accuracy: 0.8772
# Epoch 12/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9550
# Epoch 12: val_accuracy improved from 0.87921 to 0.88317, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 31s 473ms/step - loss: 0.1332 - accuracy: 0.9550 - val_loss: 0.4329 - val_accuracy: 0.8832
# Epoch 13/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9649
# Epoch 13: val_accuracy did not improve from 0.88317
# 64/64 [==============================] - 26s 393ms/step - loss: 0.1152 - accuracy: 0.9649 - val_loss: 0.4340 - val_accuracy: 0.8812
# Epoch 14/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9683
# Epoch 14: val_accuracy did not improve from 0.88317
# 64/64 [==============================] - 21s 327ms/step - loss: 0.0980 - accuracy: 0.9683 - val_loss: 0.4260 - val_accuracy: 0.8812
# Epoch 15/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9664
# Epoch 15: val_accuracy improved from 0.88317 to 0.88515, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 25s 381ms/step - loss: 0.1065 - accuracy: 0.9664 - val_loss: 0.4292 - val_accuracy: 0.8851
# Epoch 16/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9807
# Epoch 16: val_accuracy improved from 0.88515 to 0.89109, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 27s 411ms/step - loss: 0.0853 - accuracy: 0.9807 - val_loss: 0.4226 - val_accuracy: 0.8911
# Epoch 17/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9683
# Epoch 17: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 20s 299ms/step - loss: 0.1025 - accuracy: 0.9683 - val_loss: 0.4316 - val_accuracy: 0.8891
# Epoch 18/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9822
# Epoch 18: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 19s 283ms/step - loss: 0.0738 - accuracy: 0.9822 - val_loss: 0.4225 - val_accuracy: 0.8871
# Epoch 19/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9787
# Epoch 19: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 20s 303ms/step - loss: 0.0739 - accuracy: 0.9787 - val_loss: 0.4117 - val_accuracy: 0.8733
# Epoch 20/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9807
# Epoch 20: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 19s 292ms/step - loss: 0.0697 - accuracy: 0.9807 - val_loss: 0.4047 - val_accuracy: 0.8891
# Epoch 21/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9773
# Epoch 21: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 20s 297ms/step - loss: 0.0795 - accuracy: 0.9773 - val_loss: 0.4097 - val_accuracy: 0.8891
# Epoch 22/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9748
# Epoch 22: val_accuracy improved from 0.89109 to 0.89307, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 29s 450ms/step - loss: 0.0795 - accuracy: 0.9748 - val_loss: 0.4084 - val_accuracy: 0.8931
# Epoch 23/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9822
# Epoch 23: val_accuracy did not improve from 0.89307
# 64/64 [==============================] - 20s 295ms/step - loss: 0.0616 - accuracy: 0.9822 - val_loss: 0.4059 - val_accuracy: 0.8891
# Epoch 24/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9817
# Epoch 24: val_accuracy did not improve from 0.89307
# 64/64 [==============================] - 20s 293ms/step - loss: 0.0581 - accuracy: 0.9817 - val_loss: 0.4023 - val_accuracy: 0.8851
# Epoch 25/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9812
# Epoch 25: val_accuracy did not improve from 0.89307
# 64/64 [==============================] - 19s 283ms/step - loss: 0.0633 - accuracy: 0.9812 - val_loss: 0.4050 - val_accuracy: 0.8871
# Epoch 26/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9792
# Epoch 26: val_accuracy did not improve from 0.89307
# 64/64 [==============================] - 18s 279ms/step - loss: 0.0639 - accuracy: 0.9792 - val_loss: 0.4037 - val_accuracy: 0.8911
# Epoch 27/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9822
# Epoch 27: val_accuracy did not improve from 0.89307
# 64/64 [==============================] - 20s 298ms/step - loss: 0.0597 - accuracy: 0.9822 - val_loss: 0.4056 - val_accuracy: 0.8931
# Epoch 28/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9857
# Epoch 28: val_accuracy improved from 0.89307 to 0.89505, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 27s 415ms/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 0.4051 - val_accuracy: 0.8950
# Epoch 29/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9857
# Epoch 29: val_accuracy improved from 0.89505 to 0.89901, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 27s 411ms/step - loss: 0.0479 - accuracy: 0.9857 - val_loss: 0.4053 - val_accuracy: 0.8990
# Epoch 30/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9842
# Epoch 30: val_accuracy improved from 0.89901 to 0.90099, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 28s 422ms/step - loss: 0.0460 - accuracy: 0.9842 - val_loss: 0.3942 - val_accuracy: 0.9010
# Epoch 31/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9901
# Epoch 31: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 19s 293ms/step - loss: 0.0393 - accuracy: 0.9901 - val_loss: 0.4112 - val_accuracy: 0.8911
# Epoch 32/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9926
# Epoch 32: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 20s 290ms/step - loss: 0.0366 - accuracy: 0.9926 - val_loss: 0.4145 - val_accuracy: 0.8931
# Epoch 33/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9891
# Epoch 33: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 19s 284ms/step - loss: 0.0395 - accuracy: 0.9891 - val_loss: 0.4182 - val_accuracy: 0.8950
# Epoch 34/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9916
# Epoch 34: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 19s 292ms/step - loss: 0.0373 - accuracy: 0.9916 - val_loss: 0.4192 - val_accuracy: 0.8931
# Epoch 35/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9911
# Epoch 35: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 19s 281ms/step - loss: 0.0344 - accuracy: 0.9911 - val_loss: 0.4224 - val_accuracy: 0.8950
# Epoch 36/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9916
# Epoch 36: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 19s 283ms/step - loss: 0.0361 - accuracy: 0.9916 - val_loss: 0.4187 - val_accuracy: 0.8950
# Epoch 37/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9946
# Epoch 37: val_accuracy did not improve from 0.90099
# 64/64 [==============================] - 20s 303ms/step - loss: 0.0304 - accuracy: 0.9946 - val_loss: 0.4141 - val_accuracy: 0.8990
# Epoch 38/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.
100
# 64/64 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9965
# Epoch 74: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 19s 288ms/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.4408 - val_accuracy: 0.9129
# Epoch 75/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9985
# Epoch 75: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 19s 289ms/step - loss: 0.0089 - accuracy: 0.9985 - val_loss: 0.4453 - val_accuracy: 0.9109
# Epoch 76/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9985
# Epoch 76: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 20s 302ms/step - loss: 0.0111 - accuracy: 0.9985 - val_loss: 0.4579 - val_accuracy: 0.9069
# Epoch 77/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9965
# Epoch 77: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 19s 286ms/step - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.4470 - val_accuracy: 0.9089
# Epoch 78/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9970
# Epoch 78: val_accuracy improved from 0.91485 to 0.91683, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 29s 445ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.4407 - val_accuracy: 0.9168
# Epoch 79/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9970
# Epoch 79: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 289ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.4515 - val_accuracy: 0.9149
# Epoch 80/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9955
# Epoch 80: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 294ms/step - loss: 0.0183 - accuracy: 0.9955 - val_loss: 0.4515 - val_accuracy: 0.9149
# Epoch 81/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9960
# Epoch 81: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 22s 333ms/step - loss: 0.0167 - accuracy: 0.9960 - val_loss: 0.4631 - val_accuracy: 0.9149
# Epoch 82/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9975
# Epoch 82: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 21s 315ms/step - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.4522 - val_accuracy: 0.9109
# Epoch 83/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9980
# Epoch 83: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 20s 311ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.4515 - val_accuracy: 0.9109
# Epoch 84/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9980
# Epoch 84: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 291ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.4620 - val_accuracy: 0.9109
# Epoch 85/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9985
# Epoch 85: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 21s 314ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.4507 - val_accuracy: 0.9089
# Epoch 86/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9990
# Epoch 86: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 288ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.4555 - val_accuracy: 0.9030
# Epoch 87/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9975
# Epoch 87: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 288ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.4529 - val_accuracy: 0.9129
# Epoch 88/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9980
# Epoch 88: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 20s 301ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 0.4509 - val_accuracy: 0.9109
# Epoch 89/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9965
# Epoch 89: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 20s 292ms/step - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.4553 - val_accuracy: 0.9149
# Epoch 90/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9980
# Epoch 90: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 19s 287ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.4607 - val_accuracy: 0.9168
# Epoch 91/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9985
# Epoch 91: val_accuracy improved from 0.91683 to 0.92079, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 26s 407ms/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 0.4260 - val_accuracy: 0.9208
# Epoch 92/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9990
# Epoch 92: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 20s 297ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.4355 - val_accuracy: 0.9168
# Epoch 93/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9985
# Epoch 93: val_accuracy improved from 0.92079 to 0.92277, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 31s 479ms/step - loss: 0.0070 - accuracy: 0.9985 - val_loss: 0.4399 - val_accuracy: 0.9228
# Epoch 94/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9951
# Epoch 94: val_accuracy improved from 0.92277 to 0.92475, saving model to /content/drive/MyDrive/resnet_50_updated_lr_2g.h5
# 64/64 [==============================] - 30s 464ms/step - loss: 0.0095 - accuracy: 0.9951 - val_loss: 0.4407 - val_accuracy: 0.9248
# Epoch 95/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9975
# Epoch 95: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 21s 325ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.4398 - val_accuracy: 0.9208
# Epoch 96/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9980
# Epoch 96: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 20s 297ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.4453 - val_accuracy: 0.9188
# Epoch 97/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 19s 296ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4492 - val_accuracy: 0.9188
# Epoch 98/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9970
# Epoch 98: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 19s 292ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.4465 - val_accuracy: 0.9168
# Epoch 99/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9985
# Epoch 99: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 21s 313ms/step - loss: 0.0089 - accuracy: 0.9985 - val_loss: 0.4431 - val_accuracy: 0.9109
# Epoch 100/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9975
# Epoch 100: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 21s 314ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.4480 - val_accuracy: 0.9129

# %% [markdown]
# Getting best model from teh epochs

# %%
from tensorflow.keras.models import load_model
saved_model_path = "/content/drive/MyDrive/resnet_50_updated_lr_2g.h5"
best_model_50 = load_model(saved_model_path)

# %%
fig1 = plt.gcf()
plt.plot(history_50.history['accuracy'])
plt.plot(history_50.history['val_accuracy'])
plt.axis(ymin=0.4, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
fig1 = plt.gcf()
plt.plot(history_50.history['loss'])
plt.plot(history_50.history['val_loss'])
plt.axis(ymin=0, ymax=1)
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# 101 Resnet
#
# ---

# %%
resnet_ml = Sequential()

pretrain = tf.keras.applications.ResNet101(include_top= False,
                                          input_shape=(180,180,3),
                                          pooling='avg', classes=6,
                                          weights = 'imagenet')
for layers in pretrain.layers:
  layers.trainable=False


resnet_ml.add(pretrain)
# resnet_ml.add(Flatten())
resnet_ml.add(Flatten())
resnet_ml.add(Dense(units=1024, activation='relu'))  # use ReLU activation function

resnet_ml.add(Dense(units=128, activation='relu')) # use ReLU activation function

resnet_ml.add(Dense(6, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step

# %%
resnet_ml.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 2048)              42658176
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1024)              2098176
#
#  dense_4 (Dense)             (None, 128)               131200
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 44888326 (171.24 MB)
# Trainable params: 2230150 (8.51 MB)
# Non-trainable params: 42658176 (162.73 MB)
# _________________________________________________________________

# %%
resnet_ml.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# Define callbacks
checkpoint_path = "/content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5"
model_101_checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
epochs=10
history_101 = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_101_checkpoint]
)
# Out:
# Epoch 1/10
# 64/64 [==============================] - ETA: 0s - loss: 0.9952 - accuracy: 0.6548
# Epoch 1: val_accuracy improved from -inf to 0.75248, saving model to /content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5
# 64/64 [==============================] - 28s 301ms/step - loss: 0.9952 - accuracy: 0.6548 - val_loss: 0.6431 - val_accuracy: 0.7525
# Epoch 2/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.5709 - accuracy: 0.7946
# Epoch 2: val_accuracy improved from 0.75248 to 0.80594, saving model to /content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5
# 64/64 [==============================] - 20s 311ms/step - loss: 0.5713 - accuracy: 0.7948 - val_loss: 0.4942 - val_accuracy: 0.8059
# Epoch 3/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.4740 - accuracy: 0.8353
# Epoch 3: val_accuracy did not improve from 0.80594
# 64/64 [==============================] - 21s 312ms/step - loss: 0.4734 - accuracy: 0.8353 - val_loss: 0.5794 - val_accuracy: 0.7921
# Epoch 4/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.4019 - accuracy: 0.8581
# Epoch 4: val_accuracy improved from 0.80594 to 0.81188, saving model to /content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5
# 64/64 [==============================] - 22s 327ms/step - loss: 0.4021 - accuracy: 0.8581 - val_loss: 0.5032 - val_accuracy: 0.8119
# Epoch 5/10
# 64/64 [==============================] - ETA: 0s - loss: 0.3893 - accuracy: 0.8492
# Epoch 5: val_accuracy improved from 0.81188 to 0.82574, saving model to /content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5
# 64/64 [==============================] - 21s 320ms/step - loss: 0.3893 - accuracy: 0.8492 - val_loss: 0.4583 - val_accuracy: 0.8257
# Epoch 6/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.3421 - accuracy: 0.8770
# Epoch 6: val_accuracy improved from 0.82574 to 0.85149, saving model to /content/drive/MyDrive/resnet_101_10Lyr_lr_2g.h5
# 64/64 [==============================] - 25s 387ms/step - loss: 0.3416 - accuracy: 0.8773 - val_loss: 0.4060 - val_accuracy: 0.8515
# Epoch 7/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2806 - accuracy: 0.8943
# Epoch 7: val_accuracy did not improve from 0.85149
# 64/64 [==============================] - 17s 255ms/step - loss: 0.2801 - accuracy: 0.8947 - val_loss: 0.4355 - val_accuracy: 0.8396
# Epoch 8/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.9023
# Epoch 8: val_accuracy did not improve from 0.85149
# 64/64 [==============================] - 17s 255ms/step - loss: 0.2795 - accuracy: 0.9021 - val_loss: 0.4614 - val_accuracy: 0.8475
# Epoch 9/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2361 - accuracy: 0.9137
# Epoch 9: val_accuracy did not improve from 0.85149
# 64/64 [==============================] - 17s 262ms/step - loss: 0.2357 - accuracy: 0.9139 - val_loss: 0.4264 - val_accuracy: 0.8515
# Epoch 10/10
# 63/64 [============================>.] - ETA: 0s - loss: 0.2326 - accuracy: 0.9132
# Epoch 10: val_accuracy did not improve from 0.85149
# 64/64 [==============================] - 17s 251ms/step - loss: 0.2321 - accuracy: 0.9135 - val_loss: 0.5386 - val_accuracy: 0.8238

# %% [markdown]
# Training the complete model

# %%
resnet_ml.optimizer.get_config()["name"]
# Out:
# 'Adam'

# %%
checkpoint_path = "/content/drive/MyDrive/resnet_101_updated_lr_2g.h5"
model_checkpoint_full = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
for layers in resnet_ml.layers:
  layers.trainable = True

resnet_ml.compile(optimizer=Adam(learning_rate=0.0000055), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
resnet_ml.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 2048)              42658176
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1024)              2098176
#
#  dense_4 (Dense)             (None, 128)               131200
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 44888326 (171.24 MB)
# Trainable params: 44782982 (170.83 MB)
# Non-trainable params: 105344 (411.50 KB)
# _________________________________________________________________

# %%
epochs=100
history_101 = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_checkpoint_full]
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.7839
# Epoch 1: val_accuracy improved from -inf to 0.87723, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 110s 554ms/step - loss: 0.6203 - accuracy: 0.7839 - val_loss: 0.4047 - val_accuracy: 0.8772
# Epoch 2/100
# 64/64 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.8640
# Epoch 2: val_accuracy did not improve from 0.87723
# 64/64 [==============================] - 29s 439ms/step - loss: 0.3986 - accuracy: 0.8640 - val_loss: 0.3938 - val_accuracy: 0.8772
# Epoch 3/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8991
# Epoch 3: val_accuracy did not improve from 0.87723
# 64/64 [==============================] - 32s 493ms/step - loss: 0.2924 - accuracy: 0.8991 - val_loss: 0.3947 - val_accuracy: 0.8733
# Epoch 4/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.9095
# Epoch 4: val_accuracy did not improve from 0.87723
# 64/64 [==============================] - 32s 489ms/step - loss: 0.2621 - accuracy: 0.9095 - val_loss: 0.3875 - val_accuracy: 0.8673
# Epoch 5/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9263
# Epoch 5: val_accuracy did not improve from 0.87723
# 64/64 [==============================] - 32s 482ms/step - loss: 0.2321 - accuracy: 0.9263 - val_loss: 0.3742 - val_accuracy: 0.8733
# Epoch 6/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9367
# Epoch 6: val_accuracy improved from 0.87723 to 0.88317, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 56s 872ms/step - loss: 0.1997 - accuracy: 0.9367 - val_loss: 0.3578 - val_accuracy: 0.8832
# Epoch 7/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9491
# Epoch 7: val_accuracy improved from 0.88317 to 0.88911, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 51s 783ms/step - loss: 0.1595 - accuracy: 0.9491 - val_loss: 0.3547 - val_accuracy: 0.8891
# Epoch 8/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9486
# Epoch 8: val_accuracy did not improve from 0.88911
# 64/64 [==============================] - 31s 478ms/step - loss: 0.1542 - accuracy: 0.9486 - val_loss: 0.3493 - val_accuracy: 0.8832
# Epoch 9/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9510
# Epoch 9: val_accuracy did not improve from 0.88911
# 64/64 [==============================] - 32s 487ms/step - loss: 0.1439 - accuracy: 0.9510 - val_loss: 0.3480 - val_accuracy: 0.8891
# Epoch 10/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9550
# Epoch 10: val_accuracy improved from 0.88911 to 0.89703, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 47s 718ms/step - loss: 0.1367 - accuracy: 0.9550 - val_loss: 0.3427 - val_accuracy: 0.8970
# Epoch 11/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9585
# Epoch 11: val_accuracy improved from 0.89703 to 0.90891, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 58s 908ms/step - loss: 0.1204 - accuracy: 0.9585 - val_loss: 0.3337 - val_accuracy: 0.9089
# Epoch 12/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9664
# Epoch 12: val_accuracy improved from 0.90891 to 0.91089, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 64s 995ms/step - loss: 0.1037 - accuracy: 0.9664 - val_loss: 0.3246 - val_accuracy: 0.9109
# Epoch 13/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9664
# Epoch 13: val_accuracy did not improve from 0.91089
# 64/64 [==============================] - 31s 464ms/step - loss: 0.0971 - accuracy: 0.9664 - val_loss: 0.3238 - val_accuracy: 0.9109
# Epoch 14/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9669
# Epoch 14: val_accuracy did not improve from 0.91089
# 64/64 [==============================] - 29s 442ms/step - loss: 0.0978 - accuracy: 0.9669 - val_loss: 0.3170 - val_accuracy: 0.9089
# Epoch 15/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9748
# Epoch 15: val_accuracy did not improve from 0.91089
# 64/64 [==============================] - 29s 445ms/step - loss: 0.0794 - accuracy: 0.9748 - val_loss: 0.3107 - val_accuracy: 0.9109
# Epoch 16/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9708
# Epoch 16: val_accuracy improved from 0.91089 to 0.91485, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 56s 875ms/step - loss: 0.0907 - accuracy: 0.9708 - val_loss: 0.3100 - val_accuracy: 0.9149
# Epoch 17/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9758
# Epoch 17: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 31s 471ms/step - loss: 0.0791 - accuracy: 0.9758 - val_loss: 0.3093 - val_accuracy: 0.9089
# Epoch 18/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9807
# Epoch 18: val_accuracy did not improve from 0.91485
# 64/64 [==============================] - 30s 450ms/step - loss: 0.0664 - accuracy: 0.9807 - val_loss: 0.3100 - val_accuracy: 0.9069
# Epoch 19/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9832
# Epoch 19: val_accuracy improved from 0.91485 to 0.91683, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 57s 895ms/step - loss: 0.0618 - accuracy: 0.9832 - val_loss: 0.3007 - val_accuracy: 0.9168
# Epoch 20/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9822
# Epoch 20: val_accuracy did not improve from 0.91683
# 64/64 [==============================] - 29s 449ms/step - loss: 0.0574 - accuracy: 0.9822 - val_loss: 0.3035 - val_accuracy: 0.9149
# Epoch 21/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9842
# Epoch 21: val_accuracy improved from 0.91683 to 0.91881, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 54s 840ms/step - loss: 0.0549 - accuracy: 0.9842 - val_loss: 0.3117 - val_accuracy: 0.9188
# Epoch 22/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9847
# Epoch 22: val_accuracy did not improve from 0.91881
# 64/64 [==============================] - 30s 453ms/step - loss: 0.0608 - accuracy: 0.9847 - val_loss: 0.3008 - val_accuracy: 0.9168
# Epoch 23/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9896
# Epoch 23: val_accuracy did not improve from 0.91881
# 64/64 [==============================] - 29s 451ms/step - loss: 0.0485 - accuracy: 0.9896 - val_loss: 0.3056 - val_accuracy: 0.9149
# Epoch 24/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9866
# Epoch 24: val_accuracy did not improve from 0.91881
# 64/64 [==============================] - 29s 441ms/step - loss: 0.0426 - accuracy: 0.9866 - val_loss: 0.3075 - val_accuracy: 0.9129
# Epoch 25/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9886
# Epoch 25: val_accuracy did not improve from 0.91881
# 64/64 [==============================] - 29s 450ms/step - loss: 0.0428 - accuracy: 0.9886 - val_loss: 0.2981 - val_accuracy: 0.9149
# Epoch 26/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9881
# Epoch 26: val_accuracy did not improve from 0.91881
# 64/64 [==============================] - 32s 485ms/step - loss: 0.0453 - accuracy: 0.9881 - val_loss: 0.2941 - val_accuracy: 0.9168
# Epoch 27/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9891
# Epoch 27: val_accuracy improved from 0.91881 to 0.92079, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 50s 774ms/step - loss: 0.0428 - accuracy: 0.9891 - val_loss: 0.2906 - val_accuracy: 0.9208
# Epoch 28/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9970
# Epoch 28: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 31s 472ms/step - loss: 0.0290 - accuracy: 0.9970 - val_loss: 0.2965 - val_accuracy: 0.9208
# Epoch 29/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9921
# Epoch 29: val_accuracy improved from 0.92079 to 0.92475, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 55s 861ms/step - loss: 0.0324 - accuracy: 0.9921 - val_loss: 0.2921 - val_accuracy: 0.9248
# Epoch 30/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9901
# Epoch 30: val_accuracy did not improve from 0.92475
# 64/64 [==============================] - 31s 470ms/step - loss: 0.0364 - accuracy: 0.9901 - val_loss: 0.2924 - val_accuracy: 0.9228
# Epoch 31/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9921
# Epoch 31: val_accuracy did not improve from 0.92475
# 64/64 [==============================] -
ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.3226 - val_accuracy: 0.9228
# Epoch 77/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9980
# Epoch 77: val_accuracy did not improve from 0.92871
# 64/64 [==============================] - 30s 453ms/step - loss: 0.0098 - accuracy: 0.9980 - val_loss: 0.3245 - val_accuracy: 0.9287
# Epoch 78/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9960
# Epoch 78: val_accuracy did not improve from 0.92871
# 64/64 [==============================] - 30s 460ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.3123 - val_accuracy: 0.9188
# Epoch 79/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9975
# Epoch 79: val_accuracy improved from 0.92871 to 0.93069, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 58s 904ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.3251 - val_accuracy: 0.9307
# Epoch 80/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9985
# Epoch 80: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 30s 467ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.3281 - val_accuracy: 0.9267
# Epoch 81/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9990
# Epoch 81: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 32s 484ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.3401 - val_accuracy: 0.9248
# Epoch 82/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9985
# Epoch 82: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 30s 449ms/step - loss: 0.0083 - accuracy: 0.9985 - val_loss: 0.3252 - val_accuracy: 0.9228
# Epoch 83/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9985
# Epoch 83: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 29s 448ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.3298 - val_accuracy: 0.9228
# Epoch 84/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9980
# Epoch 84: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 29s 446ms/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 0.3344 - val_accuracy: 0.9188
# Epoch 85/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9985
# Epoch 85: val_accuracy did not improve from 0.93069
# 64/64 [==============================] - 32s 490ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.3299 - val_accuracy: 0.9228
# Epoch 86/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9990
# Epoch 86: val_accuracy improved from 0.93069 to 0.93465, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 52s 796ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.3140 - val_accuracy: 0.9347
# Epoch 87/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9980
# Epoch 87: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 30s 456ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.3237 - val_accuracy: 0.9327
# Epoch 88/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 88: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 30s 453ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.3253 - val_accuracy: 0.9267
# Epoch 89/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9995
# Epoch 89: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 29s 439ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.3176 - val_accuracy: 0.9307
# Epoch 90/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9990
# Epoch 90: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 30s 453ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3136 - val_accuracy: 0.9327
# Epoch 91/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9990
# Epoch 91: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 30s 459ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.3116 - val_accuracy: 0.9327
# Epoch 92/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9980
# Epoch 92: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 29s 445ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.3223 - val_accuracy: 0.9287
# Epoch 93/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9990
# Epoch 93: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 29s 449ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.3268 - val_accuracy: 0.9307
# Epoch 94/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9980
# Epoch 94: val_accuracy did not improve from 0.93465
# 64/64 [==============================] - 29s 442ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.3271 - val_accuracy: 0.9347
# Epoch 95/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9995
# Epoch 95: val_accuracy improved from 0.93465 to 0.93861, saving model to /content/drive/MyDrive/resnet_101_updated_lr_2g.h5
# 64/64 [==============================] - 58s 897ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.3342 - val_accuracy: 0.9386
# Epoch 96/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9975
# Epoch 96: val_accuracy did not improve from 0.93861
# 64/64 [==============================] - 29s 447ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.3117 - val_accuracy: 0.9386
# Epoch 97/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980
# Epoch 97: val_accuracy did not improve from 0.93861
# 64/64 [==============================] - 30s 455ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.3069 - val_accuracy: 0.9366
# Epoch 98/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9995
# Epoch 98: val_accuracy did not improve from 0.93861
# 64/64 [==============================] - 29s 444ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.3106 - val_accuracy: 0.9366
# Epoch 99/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9990
# Epoch 99: val_accuracy did not improve from 0.93861
# 64/64 [==============================] - 29s 450ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.3058 - val_accuracy: 0.9366
# Epoch 100/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9980
# Epoch 100: val_accuracy did not improve from 0.93861
# 64/64 [==============================] - 29s 444ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.3271 - val_accuracy: 0.9307

# %%
from tensorflow.keras.models import load_model
saved_model_path = "/content/drive/MyDrive/resnet_101_updated_lr_2g.h5"
best_model_101 = load_model(saved_model_path)

# %%
fig1 = plt.gcf()
plt.plot(history_101.history['accuracy'])
plt.plot(history_101.history['val_accuracy'])
plt.axis(ymin=0.4, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
fig1 = plt.gcf()
plt.plot(history_101.history['loss'])
plt.plot(history_101.history['val_loss'])
plt.axis(ymin=0, ymax=1)
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# # 152 Resnet
#
# ---

# %%
resnet_ml = Sequential()

pretrain = tf.keras.applications.ResNet152(include_top= False,
                                          input_shape=(180,180,3),
                                          pooling='avg', classes=6,
                                          weights = 'imagenet')
for layers in pretrain.layers:
  layers.trainable=False


resnet_ml.add(pretrain)
# resnet_ml.add(Flatten())
resnet_ml.add(Flatten())
resnet_ml.add(Dense(units=1024, activation='relu'))  # use ReLU activation function

resnet_ml.add(Dense(units=128, activation='relu')) # use ReLU activation function

resnet_ml.add(Dense(6, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 5s 0us/step

# %%
resnet_ml.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 1024)              2098176
#
#  dense_7 (Dense)             (None, 128)               131200
#
#  dense_8 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 60601094 (231.17 MB)
# Trainable params: 2230150 (8.51 MB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
resnet_ml.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# Define callbacks
checkpoint_path = "/content/drive/MyDrive/resnet_152_10Lyr_lr.h5"
model_101_checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
epochs=10
history_152_10 = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_101_checkpoint]
)
# Out:
# Epoch 1/10
# 64/64 [==============================] - ETA: 0s - loss: 0.9879 - accuracy: 0.6617
# Epoch 1: val_accuracy improved from -inf to 0.79010, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 35s 357ms/step - loss: 0.9879 - accuracy: 0.6617 - val_loss: 0.6021 - val_accuracy: 0.7901
# Epoch 2/10
# 64/64 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.7953
# Epoch 2: val_accuracy did not improve from 0.79010
# 64/64 [==============================] - 21s 314ms/step - loss: 0.5821 - accuracy: 0.7953 - val_loss: 0.5836 - val_accuracy: 0.7881
# Epoch 3/10
# 64/64 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.8304
# Epoch 3: val_accuracy improved from 0.79010 to 0.80792, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 26s 395ms/step - loss: 0.4805 - accuracy: 0.8304 - val_loss: 0.5687 - val_accuracy: 0.8079
# Epoch 4/10
# 64/64 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8477
# Epoch 4: val_accuracy improved from 0.80792 to 0.82376, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 32s 487ms/step - loss: 0.4088 - accuracy: 0.8477 - val_loss: 0.5673 - val_accuracy: 0.8238
# Epoch 5/10
# 64/64 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8546
# Epoch 5: val_accuracy did not improve from 0.82376
# 64/64 [==============================] - 18s 270ms/step - loss: 0.4062 - accuracy: 0.8546 - val_loss: 0.5289 - val_accuracy: 0.8059
# Epoch 6/10
# 64/64 [==============================] - ETA: 0s - loss: 0.3881 - accuracy: 0.8576
# Epoch 6: val_accuracy improved from 0.82376 to 0.82970, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 26s 400ms/step - loss: 0.3881 - accuracy: 0.8576 - val_loss: 0.4822 - val_accuracy: 0.8297
# Epoch 7/10
# 64/64 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8956
# Epoch 7: val_accuracy improved from 0.82970 to 0.84158, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 28s 437ms/step - loss: 0.3069 - accuracy: 0.8956 - val_loss: 0.4741 - val_accuracy: 0.8416
# Epoch 8/10
# 64/64 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8976
# Epoch 8: val_accuracy improved from 0.84158 to 0.84356, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 28s 425ms/step - loss: 0.2736 - accuracy: 0.8976 - val_loss: 0.4153 - val_accuracy: 0.8436
# Epoch 9/10
# 64/64 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9149
# Epoch 9: val_accuracy did not improve from 0.84356
# 64/64 [==============================] - 19s 289ms/step - loss: 0.2391 - accuracy: 0.9149 - val_loss: 0.4956 - val_accuracy: 0.8376
# Epoch 10/10
# 64/64 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9050
# Epoch 10: val_accuracy improved from 0.84356 to 0.84950, saving model to /content/drive/MyDrive/resnet_152_10Lyr_lr.h5
# 64/64 [==============================] - 28s 428ms/step - loss: 0.2597 - accuracy: 0.9050 - val_loss: 0.4108 - val_accuracy: 0.8495

# %% [markdown]
# Training the complete model

# %%
resnet_ml.optimizer.get_config()["name"]
# Out:
# 'Adam'

# %%
checkpoint_path = "/content/drive/MyDrive/resnet_152_updated_lr_2g.h5"
model_checkpoint_full = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)

# %%
for layers in resnet_ml.layers:
  layers.trainable = True

resnet_ml.compile(optimizer=Adam(learning_rate=0.0000055), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
resnet_ml.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 1024)              2098176
#
#  dense_7 (Dense)             (None, 128)               131200
#
#  dense_8 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 60601094 (231.17 MB)
# Trainable params: 60449670 (230.60 MB)
# Non-trainable params: 151424 (591.50 KB)
# _________________________________________________________________

# %%
epochs=100
history_152 = resnet_ml.fit(
    augmented_train_ds,
    validation_data = val_ds,
    epochs = epochs,
    shuffle = True,
    callbacks=[model_checkpoint_full]
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.7760
# Epoch 1: val_accuracy improved from -inf to 0.87921, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 177s 1s/step - loss: 0.6090 - accuracy: 0.7760 - val_loss: 0.3780 - val_accuracy: 0.8792
# Epoch 2/100
# 64/64 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8818
# Epoch 2: val_accuracy improved from 0.87921 to 0.88515, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 102s 2s/step - loss: 0.3295 - accuracy: 0.8818 - val_loss: 0.3551 - val_accuracy: 0.8851
# Epoch 3/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.9070
# Epoch 3: val_accuracy did not improve from 0.88515
# 64/64 [==============================] - 46s 711ms/step - loss: 0.2709 - accuracy: 0.9070 - val_loss: 0.3603 - val_accuracy: 0.8752
# Epoch 4/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9253
# Epoch 4: val_accuracy did not improve from 0.88515
# 64/64 [==============================] - 40s 612ms/step - loss: 0.2224 - accuracy: 0.9253 - val_loss: 0.3721 - val_accuracy: 0.8673
# Epoch 5/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9377
# Epoch 5: val_accuracy did not improve from 0.88515
# 64/64 [==============================] - 43s 658ms/step - loss: 0.1850 - accuracy: 0.9377 - val_loss: 0.3603 - val_accuracy: 0.8812
# Epoch 6/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9441
# Epoch 6: val_accuracy did not improve from 0.88515
# 64/64 [==============================] - 41s 628ms/step - loss: 0.1733 - accuracy: 0.9441 - val_loss: 0.3552 - val_accuracy: 0.8851
# Epoch 7/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9461
# Epoch 7: val_accuracy improved from 0.88515 to 0.88713, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 97s 2s/step - loss: 0.1624 - accuracy: 0.9461 - val_loss: 0.3489 - val_accuracy: 0.8871
# Epoch 8/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9585
# Epoch 8: val_accuracy did not improve from 0.88713
# 64/64 [==============================] - 41s 632ms/step - loss: 0.1354 - accuracy: 0.9585 - val_loss: 0.3442 - val_accuracy: 0.8871
# Epoch 9/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9575
# Epoch 9: val_accuracy improved from 0.88713 to 0.89109, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 87s 1s/step - loss: 0.1254 - accuracy: 0.9575 - val_loss: 0.3439 - val_accuracy: 0.8911
# Epoch 10/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9659
# Epoch 10: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 42s 643ms/step - loss: 0.1093 - accuracy: 0.9659 - val_loss: 0.3432 - val_accuracy: 0.8911
# Epoch 11/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9723
# Epoch 11: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 43s 655ms/step - loss: 0.0991 - accuracy: 0.9723 - val_loss: 0.3456 - val_accuracy: 0.8911
# Epoch 12/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9669
# Epoch 12: val_accuracy did not improve from 0.89109
# 64/64 [==============================] - 41s 625ms/step - loss: 0.1018 - accuracy: 0.9669 - val_loss: 0.3444 - val_accuracy: 0.8911
# Epoch 13/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9728
# Epoch 13: val_accuracy improved from 0.89109 to 0.90297, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 87s 1s/step - loss: 0.0976 - accuracy: 0.9728 - val_loss: 0.3369 - val_accuracy: 0.9030
# Epoch 14/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9822
# Epoch 14: val_accuracy did not improve from 0.90297
# 64/64 [==============================] - 41s 625ms/step - loss: 0.0736 - accuracy: 0.9822 - val_loss: 0.3394 - val_accuracy: 0.8950
# Epoch 15/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9777
# Epoch 15: val_accuracy did not improve from 0.90297
# 64/64 [==============================] - 42s 639ms/step - loss: 0.0819 - accuracy: 0.9777 - val_loss: 0.3525 - val_accuracy: 0.8990
# Epoch 16/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9748
# Epoch 16: val_accuracy did not improve from 0.90297
# 64/64 [==============================] - 41s 626ms/step - loss: 0.0813 - accuracy: 0.9748 - val_loss: 0.3478 - val_accuracy: 0.9030
# Epoch 17/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9876
# Epoch 17: val_accuracy improved from 0.90297 to 0.90891, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 95s 1s/step - loss: 0.0568 - accuracy: 0.9876 - val_loss: 0.3413 - val_accuracy: 0.9089
# Epoch 18/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9852
# Epoch 18: val_accuracy did not improve from 0.90891
# 64/64 [==============================] - 41s 627ms/step - loss: 0.0650 - accuracy: 0.9852 - val_loss: 0.3335 - val_accuracy: 0.9089
# Epoch 19/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9827
# Epoch 19: val_accuracy did not improve from 0.90891
# 64/64 [==============================] - 40s 615ms/step - loss: 0.0596 - accuracy: 0.9827 - val_loss: 0.3321 - val_accuracy: 0.9089
# Epoch 20/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9881
# Epoch 20: val_accuracy did not improve from 0.90891
# 64/64 [==============================] - 41s 629ms/step - loss: 0.0514 - accuracy: 0.9881 - val_loss: 0.3243 - val_accuracy: 0.9069
# Epoch 21/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9886
# Epoch 21: val_accuracy improved from 0.90891 to 0.91089, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 91s 1s/step - loss: 0.0523 - accuracy: 0.9886 - val_loss: 0.3195 - val_accuracy: 0.9109
# Epoch 22/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9852
# Epoch 22: val_accuracy did not improve from 0.91089
# 64/64 [==============================] - 40s 616ms/step - loss: 0.0562 - accuracy: 0.9852 - val_loss: 0.3194 - val_accuracy: 0.9089
# Epoch 23/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9866
# Epoch 23: val_accuracy improved from 0.91089 to 0.91485, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 89s 1s/step - loss: 0.0451 - accuracy: 0.9866 - val_loss: 0.3247 - val_accuracy: 0.9149
# Epoch 24/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9946
# Epoch 24: val_accuracy improved from 0.91485 to 0.91881, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 95s 1s/step - loss: 0.0381 - accuracy: 0.9946 - val_loss: 0.3181 - val_accuracy: 0.9188
# Epoch 25/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9921
# Epoch 25: val_accuracy improved from 0.91881 to 0.92079, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 92s 1s/step - loss: 0.0343 - accuracy: 0.9921 - val_loss: 0.3260 - val_accuracy: 0.9208
# Epoch 26/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9906
# Epoch 26: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 39s 601ms/step - loss: 0.0335 - accuracy: 0.9906 - val_loss: 0.3273 - val_accuracy: 0.9129
# Epoch 27/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9921
# Epoch 27: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 41s 631ms/step - loss: 0.0350 - accuracy: 0.9921 - val_loss: 0.3257 - val_accuracy: 0.9109
# Epoch 28/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9906
# Epoch 28: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 39s 606ms/step - loss: 0.0409 - accuracy: 0.9906 - val_loss: 0.3278 - val_accuracy: 0.9109
# Epoch 29/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9921
# Epoch 29: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 41s 622ms/step - loss: 0.0321 - accuracy: 0.9921 - val_loss: 0.3184 - val_accuracy: 0.9129
# Epoch 30/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9941
# Epoch 30: val_accuracy did not improve from 0.92079
# 64/64 [==============================] - 40s 609ms/step - loss: 0.0278 - accuracy: 0.9941 - val_loss: 0.3195 - val_accuracy: 0.9168
# Epoch 31/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.
ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.3412 - val_accuracy: 0.9208
# Epoch 76/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9980
# Epoch 76: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 613ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.3430 - val_accuracy: 0.9149
# Epoch 77/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9960
# Epoch 77: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 632ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.3189 - val_accuracy: 0.9267
# Epoch 78/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9975
# Epoch 78: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 625ms/step - loss: 0.0102 - accuracy: 0.9975 - val_loss: 0.3239 - val_accuracy: 0.9287
# Epoch 79/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9975
# Epoch 79: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 42s 653ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.3220 - val_accuracy: 0.9287
# Epoch 80/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9990
# Epoch 80: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 620ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3191 - val_accuracy: 0.9307
# Epoch 81/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9980
# Epoch 81: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 624ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.3286 - val_accuracy: 0.9287
# Epoch 82/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9980
# Epoch 82: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 42s 651ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.3266 - val_accuracy: 0.9307
# Epoch 83/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9975
# Epoch 83: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 619ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.3232 - val_accuracy: 0.9287
# Epoch 84/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9980
# Epoch 84: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 621ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.3352 - val_accuracy: 0.9267
# Epoch 85/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9990
# Epoch 85: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 629ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3329 - val_accuracy: 0.9307
# Epoch 86/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980
# Epoch 86: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 632ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3272 - val_accuracy: 0.9248
# Epoch 87/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9980
# Epoch 87: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 625ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.3315 - val_accuracy: 0.9267
# Epoch 88/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9995
# Epoch 88: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 43s 658ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.3331 - val_accuracy: 0.9287
# Epoch 89/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9985
# Epoch 89: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 616ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.3403 - val_accuracy: 0.9248
# Epoch 90/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9995
# Epoch 90: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 43s 653ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.3404 - val_accuracy: 0.9267
# Epoch 91/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9970
# Epoch 91: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 626ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.3548 - val_accuracy: 0.9287
# Epoch 92/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9980
# Epoch 92: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 618ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.3522 - val_accuracy: 0.9287
# Epoch 93/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9980
# Epoch 93: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 43s 655ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.3163 - val_accuracy: 0.9287
# Epoch 94/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9980
# Epoch 94: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 40s 611ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.3412 - val_accuracy: 0.9267
# Epoch 95/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9985
# Epoch 95: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 42s 652ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.3404 - val_accuracy: 0.9307
# Epoch 96/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 96: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 628ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.3207 - val_accuracy: 0.9366
# Epoch 97/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9975
# Epoch 97: val_accuracy did not improve from 0.93663
# 64/64 [==============================] - 41s 626ms/step - loss: 0.0057 - accuracy: 0.9975 - val_loss: 0.3362 - val_accuracy: 0.9366
# Epoch 98/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9990
# Epoch 98: val_accuracy improved from 0.93663 to 0.94059, saving model to /content/drive/MyDrive/resnet_152_updated_lr_2g.h5
# 64/64 [==============================] - 91s 1s/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3067 - val_accuracy: 0.9406
# Epoch 99/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9985
# Epoch 99: val_accuracy did not improve from 0.94059
# 64/64 [==============================] - 42s 643ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.3081 - val_accuracy: 0.9406
# Epoch 100/100
# 64/64 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9985
# Epoch 100: val_accuracy did not improve from 0.94059
# 64/64 [==============================] - 42s 653ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.3157 - val_accuracy: 0.9386

# %%
from tensorflow.keras.models import load_model
saved_model_path = "/content/drive/MyDrive/resnet_152_updated_lr_2g.h5"
best_model_152 = load_model(saved_model_path)

# %%
fig1 = plt.gcf()
plt.plot(history_152.history['accuracy'])
plt.plot(history_152.history['val_accuracy'])
plt.axis(ymin=0.4, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
fig1 = plt.gcf()
plt.plot(history_152.history['loss'])
plt.plot(history_152.history['val_loss'])
plt.axis(ymin=0, ymax=1)
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# Prediction and visualiasation

# %%
# Plot training accuracies
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['accuracy'], label='ResNet-50 Training Accuracy')
plt.plot(history_101.history['accuracy'], label='ResNet-101 Training Accuracy')
plt.plot(history_152.history['accuracy'], label='ResNet-152 Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracies of Models')
plt.show()

# Plot validation accuracies
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['val_accuracy'], label='ResNet-50 Validation Accuracy')
plt.plot(history_101.history['val_accuracy'], label='ResNet-101 Validation Accuracy')
plt.plot(history_152.history['val_accuracy'], label='ResNet-152 Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Validation Accuracies of Models')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['val_loss'], label='ResNet-50 Validation loss')
plt.plot(history_101.history['val_loss'], label='ResNet-101 Validation loss')
plt.plot(history_152.history['val_loss'], label='ResNet-152 Validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Validation loss of Models')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['loss'], label='ResNet-50 training loss')
plt.plot(history_101.history['loss'], label='ResNet-101 training loss')
plt.plot(history_152.history['loss'], label='ResNet-152 training loss')

plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Training Loss of Models')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['loss'], label='ResNet-50 training loss')
plt.plot(history_101.history['loss'], label='ResNet-101 training loss')
plt.plot(history_152.history['loss'], label='ResNet-152 training loss')

plt.plot(history_50.history['val_loss'], label='ResNet-50 Validation loss')
plt.plot(history_101.history['val_loss'], label='ResNet-101 Validation loss')
plt.plot(history_152.history['val_loss'], label='ResNet-152 Validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Loss of Models')
plt.show()

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Assuming you have three models named model1, model2, and model3
# Replace these with your actual model instances
model1 = best_model_50
model2 = best_model_101
model3 = best_model_152

# Assuming glass is a list of file paths
imagees = ["/content/drive/MyDrive/glass477.jpg",
         "/content/drive/MyDrive/plastic472.jpg"]

# Define the desired height and width for resizing
img_height, img_width = 180, 180  # Change these dimensions as needed

# Loop through the images
for img_path in imagees:
    # Read the image using OpenCV
    img = cv2.imread(img_path)

    # Check if the image is successfully loaded
    if img is not None:
        # Resize the image
        img_resize = cv2.resize(img, (img_width, img_height))

        # Add an extra dimension to the image to make it compatible with the models
        img = np.expand_dims(img_resize, axis=0)

        # Make predictions using each model
        prediction1 = model1.predict(img)
        prediction2 = model2.predict(img)
        prediction3 = model3.predict(img)

        # Display the image
        cv2_imshow(img_resize)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        # Print or use the predictions as needed
        print(f"Image: {img_path}")
        print("Resnet50 Prediction:", class_names[np.argmax(prediction1)])
        print("Resnet101 Prediction:", class_names[np.argmax(prediction2)])
        print("Resnet152 3 Prediction:", class_names[np.argmax(prediction3)])
        print("-" * 30)
    else:
        print(f"Error: Unable to read the image at path {img_path}.")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# <PIL.Image.Image image mode=RGB size=180x180>
# Image: /content/drive/MyDrive/glass477.jpg
# Resnet50 Prediction: glass
# Resnet101 Prediction: glass
# Resnet152 3 Prediction: glass
# ------------------------------
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 53ms/step
# <PIL.Image.Image image mode=RGB size=180x180>
# Image: /content/drive/MyDrive/plastic472.jpg
# Resnet50 Prediction: plastic
# Resnet101 Prediction: plastic
# Resnet152 3 Prediction: plastic
# ------------------------------

# %%
# Plot training accuracies
plt.figure(figsize=(12, 6))
plt.plot(history_50.history['accuracy'], label='ResNet-50 Training Accuracy')
plt.plot(history_101.history['accuracy'], label='ResNet-101 Training Accuracy')
plt.plot(history_152.history['accuracy'], label='ResNet-152 Training Accuracy')
plt.plot(history_50.history['val_accuracy'], label='ResNet-50 Validation Accuracy')
plt.plot(history_101.history['val_accuracy'], label='ResNet-101 Validation Accuracy')
plt.plot(history_152.history['val_accuracy'], label='ResNet-152 Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracies of Models')
plt.show()

# Plot validation accuracies
# plt.figure(figsize=(12, 6))

# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.title('Validation Accuracies of Different Models')
# plt.show()

# %%
x = best_model_50.history.history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-bf3fb060472d> in <cell line: 1>()
# ----> 1 x = best_model_50.history.history
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %%
# Plot the training and validation accuracy of each model
plt.plot(best_model_50['accuracy'])
plt.plot(best_model_50['val_accuracy'])
plt.plot(best_model_101['accuracy'])
plt.plot(best_model_101['val_accuracy'])
plt.plot(best_model_152['accuracy'])
plt.plot(best_model_152['val_accuracy'])

# Add labels and legend
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Resnet 50 Training', 'Resnet 50 Validation', 'best_model_101 Training', 'best_model_101 Validation', 'best_model_152 Training', 'best_model_152 Validation'], loc='lower right')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-dd42d4449657> in <cell line: 6>()
#       4
#       5 # Plot the training and validation accuracy of each model
# ----> 6 plt.plot(best_model_50['accuracy'])
#       7 plt.plot(best_model_50['val_accuracy'])
#       8 plt.plot(best_model_101['accuracy'])
#
# TypeError: 'Sequential' object is not subscriptable

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.4, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
import cv2
import numpy as np

# Assuming you have three models named model1, model2, and model3
# Replace these with your actual model instances
model1 = ...
model2 = ...
model3 = ...

# Assuming glass is a list of file paths
glass = ["path/to/image1.jpg", "path/to/image2.jpg", "path/to/image3.jpg",
         "path/to/image4.jpg", "path/to/image5.jpg", "path/to/image6.jpg"]

# Define the desired height and width for resizing
img_height, img_width = 224, 224  # Change these dimensions as needed

# Loop through the images
for img_path in glass:
    # Read the image using OpenCV
    img = cv2.imread(img_path)

    # Check if the image is successfully loaded
    if img is not None:
        # Resize the image
        img_resize = cv2.resize(img, (img_width, img_height))

        # Add an extra dimension to the image to make it compatible with the models
        img = np.expand_dims(img_resize, axis=0)

        # Make predictions using each model
        prediction1 = model1.predict(img)
        prediction2 = model2.predict(img)
        prediction3 = model3.predict(img)

        # Display the image
        cv2.imshow("Image", img_resize)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        # Print or use the predictions as needed
        print(f"Image: {img_path}")
        print("Model 1 Prediction:", prediction1)
        print("Model 2 Prediction:", prediction2)
        print("Model 3 Prediction:", prediction3)
        print("-" * 30)
    else:
        print(f"Error: Unable to read the image at path {img_path}.")

# %%
import cv2
import numpy as np
img = cv2.imread(str(glass[110]))
img_resize =cv2.resize(img, (img_height, img_width))
img = np.expand_dims(img_resize, axis=0)
print(img.shape)
# Out:
# (1, 180, 180, 3)

# %%
pred = best_model_1.predict(img)
print(pred)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[2.15828695e-04 7.31977940e-01 1.78654239e-01 7.84617066e-02
#   1.06358435e-02 5.44596114e-05]]

# %%
final_pred = class_names[np.argmax(pred)]

# %%
final_pred
# Out:
# 'glass'

# %%
PIL.Image.open(str(glass[110]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>
